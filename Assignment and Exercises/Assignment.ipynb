# %%
import numpy as np
from matplotlib import pyplot as plt

def sort_function(unsorted_array):
    """
    Implement the sort function.
    
    Arguments:
    unsorted_array -- unsorted random numpy array
    
    Returns:
    sorted_array -- sorted array from smallest to largest
    """
    return False


def find(sorted_array, element_to_find):
    """
    Implement the find function. find is a function that takes an ordered array of numbers 
    and another number, returning true or false whether the element appears in the array
    
    Arguments:
    sorted_array -- sorted array from smallest to largest
    element_to_find -- element is the random number to find in the array
    
    Returns:
    Returning true or false whether the element appears in the array
    """
  return False

if __name__ == "__main__":
    # 
    len = None
    max_range = None
    min_range = None
    element_to_find = None
    
    ### START CODE HERE ###
    unsorted_array = None  # hint: you can use numpy randint()
    ### END CODER HERE ###
    
    ### START CODE HERE ###
    # plot the unsorted numbers using plt.stem
    ### END CODER HERE ###

    # Sorting the array using numpy sort function
    sorted_array_expected = np.sort(unsorted_array) 
    
    ### START CODE HERE ###
    # plot the expected sorted numbers using plt.stem
    ### END CODER HERE ###


    ### START CODE HERE ### 
    
    # 1- Call your sort function
    # sorted_array = sort_function(unsorted_array)
    # 2- Call the find function
    # find_result = find(sorted_array, element_to_find)
    # Print find result with a proper message
    
    # 3- Show the result of the sorting in a subplot grid
    # Set up a subplot grid that has height 2 and width 1,
    # and set the first such subplot as active.
    # plt.subplot(2, 1, 1)
    # Make the first plot
    # Stem plot of unsorted numbers
    # plt.title('Random number without sorting')
    # Set the second subplot as active, and make the second plot.
    # plt.subplot(2, 1, 2)
    # Stem plot of sorted numbers
    # plt.title('Random number with sorting')

    # Show the figure.
    # plt.show()
    ### END CODER HERE ###
